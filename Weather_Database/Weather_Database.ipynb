# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import json
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mwinilunga
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | sangar
# Processing Record 4 of Set 1 | kaitangata
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | coquimbo
# Processing Record 7 of Set 1 | la palma
# Processing Record 8 of Set 1 | saskylakh
# Processing Record 9 of Set 1 | sakaiminato
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | ostrovnoy
# Processing Record 12 of Set 1 | waycross
# Processing Record 13 of Set 1 | havoysund
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | the valley
# Processing Record 16 of Set 1 | maragogi
# Processing Record 17 of Set 1 | qui nhon
# Processing Record 18 of Set 1 | shar
# Processing Record 19 of Set 1 | malatya
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | te anau
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | christchurch
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | kaeo
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | castro
# Processing Record 32 of Set 1 | provideniya
# Processing Record 33 of Set 1 | poum
# Processing Record 34 of Set 1 | kodiak
# Processing Record 35 of Set 1 | riviere-au-renard
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | sarh
# Processing Record 38 of Set 1 | dikson
# Processing Record 39 of Set 1 | beatrice
# Processing Record 40 of Set 1 | avera
# Processing Record 41 of Set 1 | isangel
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | bagdarin
# Processing Record 44 of Set 1 | katherine
# Processing Record 45 of Set 1 | tasiilaq
# Processing Record 46 of Set 1 | norman wells
# Processing Record 47 of Set 1 | luderitz
# Processing Record 48 of Set 1 | hilo
# Processing Record 49 of Set 1 | katsuura
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | novo aripuana
# Processing Record 2 of Set 2 | nikolskoye
# Processing Record 3 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 2 | moron
# Processing Record 5 of Set 2 | faanui
# Processing Record 6 of Set 2 | derzhavinsk
# Processing Record 7 of Set 2 | ponta do sol
# Processing Record 8 of Set 2 | tuy hoa
# Processing Record 9 of Set 2 | saint-philippe
# Processing Record 10 of Set 2 | drayton valley
# Processing Record 11 of Set 2 | lavrentiya
# Processing Record 12 of Set 2 | matiri
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | hovd
# Processing Record 15 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 2 | port macquarie
# Processing Record 17 of Set 2 | qaanaaq
# Processing Record 18 of Set 2 | arlit
# Processing Record 19 of Set 2 | kumo
# Processing Record 20 of Set 2 | mentok
# City not found. Skipping...
# Processing Record 21 of Set 2 | airai
# Processing Record 22 of Set 2 | cabo san lucas
# Processing Record 23 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 2 | najran
# Processing Record 26 of Set 2 | meulaboh
# Processing Record 27 of Set 2 | araouane
# Processing Record 28 of Set 2 | youghal
# Processing Record 29 of Set 2 | arraial do cabo
# Processing Record 30 of Set 2 | nemuro
# Processing Record 31 of Set 2 | tigil
# Processing Record 32 of Set 2 | kapaa
# Processing Record 33 of Set 2 | xunchang
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | pevek
# Processing Record 36 of Set 2 | vaini
# Processing Record 37 of Set 2 | nanortalik
# Processing Record 38 of Set 2 | mehran
# Processing Record 39 of Set 2 | port elizabeth
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | tacotalpa
# Processing Record 42 of Set 2 | ligayan
# Processing Record 43 of Set 2 | thompson
# Processing Record 44 of Set 2 | conway
# Processing Record 45 of Set 2 | hermanus
# Processing Record 46 of Set 2 | rio grande
# Processing Record 47 of Set 2 | nantucket
# Processing Record 48 of Set 2 | hithadhoo
# Processing Record 49 of Set 2 | bengkulu
# Processing Record 50 of Set 2 | bowen
# Processing Record 1 of Set 3 | kirensk
# Processing Record 2 of Set 3 | broome
# Processing Record 3 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 3 | sioux lookout
# Processing Record 5 of Set 3 | santo antonio do ica
# Processing Record 6 of Set 3 | leningradskiy
# Processing Record 7 of Set 3 | acarau
# Processing Record 8 of Set 3 | dolzhanskaya
# Processing Record 9 of Set 3 | san cristobal
# Processing Record 10 of Set 3 | sao joao da barra
# Processing Record 11 of Set 3 | gunzenhausen
# Processing Record 12 of Set 3 | atuona
# Processing Record 13 of Set 3 | necochea
# Processing Record 14 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 3 | goderich
# Processing Record 16 of Set 3 | geraldton
# Processing Record 17 of Set 3 | san patricio
# Processing Record 18 of Set 3 | jaffna
# Processing Record 19 of Set 3 | viseu
# Processing Record 20 of Set 3 | osinovo
# Processing Record 21 of Set 3 | haines junction
# Processing Record 22 of Set 3 | rundu
# Processing Record 23 of Set 3 | lasa
# Processing Record 24 of Set 3 | beyla
# Processing Record 25 of Set 3 | kahului
# Processing Record 26 of Set 3 | hobart
# Processing Record 27 of Set 3 | namibe
# Processing Record 28 of Set 3 | san juan
# Processing Record 29 of Set 3 | lompoc
# Processing Record 30 of Set 3 | arima
# Processing Record 31 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 32 of Set 3 | aripuana
# Processing Record 33 of Set 3 | enid
# Processing Record 34 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 35 of Set 3 | neftcala
# Processing Record 36 of Set 3 | waingapu
# Processing Record 37 of Set 3 | nicoya
# Processing Record 38 of Set 3 | furano
# Processing Record 39 of Set 3 | sao filipe
# Processing Record 40 of Set 3 | coihaique
# Processing Record 41 of Set 3 | puro
# Processing Record 42 of Set 3 | palu
# Processing Record 43 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 44 of Set 3 | soyo
# Processing Record 45 of Set 3 | sao gabriel da cachoeira
# Processing Record 46 of Set 3 | gautier
# Processing Record 47 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 3 | klaksvik
# Processing Record 49 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 3 | esperance
# Processing Record 1 of Set 4 | tamandare
# Processing Record 2 of Set 4 | port hedland
# Processing Record 3 of Set 4 | constitucion
# Processing Record 4 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 4 | kieta
# Processing Record 6 of Set 4 | biak
# Processing Record 7 of Set 4 | roald
# Processing Record 8 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 4 | mahibadhoo
# Processing Record 10 of Set 4 | loubomo
# Processing Record 11 of Set 4 | bredasdorp
# Processing Record 12 of Set 4 | butaritari
# Processing Record 13 of Set 4 | torbay
# Processing Record 14 of Set 4 | kavieng
# Processing Record 15 of Set 4 | iberia
# Processing Record 16 of Set 4 | hasaki
# Processing Record 17 of Set 4 | minas
# Processing Record 18 of Set 4 | kruisfontein
# Processing Record 19 of Set 4 | lynchburg
# Processing Record 20 of Set 4 | viedma
# Processing Record 21 of Set 4 | abeche
# Processing Record 22 of Set 4 | basco
# Processing Record 23 of Set 4 | dudinka
# Processing Record 24 of Set 4 | plover
# Processing Record 25 of Set 4 | pangoa
# Processing Record 26 of Set 4 | lamar
# Processing Record 27 of Set 4 | egvekinot
# Processing Record 28 of Set 4 | lebu
# Processing Record 29 of Set 4 | varhaug
# Processing Record 30 of Set 4 | souillac
# Processing Record 31 of Set 4 | khatanga
# Processing Record 32 of Set 4 | taoudenni
# Processing Record 33 of Set 4 | robertsport
# Processing Record 34 of Set 4 | labuhan
# Processing Record 35 of Set 4 | riberalta
# Processing Record 36 of Set 4 | plettenberg bay
# Processing Record 37 of Set 4 | bathsheba
# Processing Record 38 of Set 4 | carnarvon
# Processing Record 39 of Set 4 | longyearbyen
# Processing Record 40 of Set 4 | barra
# Processing Record 41 of Set 4 | careva cuprija
# Processing Record 42 of Set 4 | babol
# Processing Record 43 of Set 4 | grantham
# Processing Record 44 of Set 4 | hobyo
# Processing Record 45 of Set 4 | bonavista
# Processing Record 46 of Set 4 | road town
# Processing Record 47 of Set 4 | uzumlu
# City not found. Skipping...
# Processing Record 48 of Set 4 | cao bang
# Processing Record 49 of Set 4 | strezhevoy
# Processing Record 50 of Set 4 | santa maria
# Processing Record 1 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 2 of Set 5 | port lincoln
# Processing Record 3 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 5 | zdounky
# Processing Record 5 of Set 5 | comodoro rivadavia
# Processing Record 6 of Set 5 | port alfred
# Processing Record 7 of Set 5 | tres picos
# Processing Record 8 of Set 5 | avarua
# Processing Record 9 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 10 of Set 5 | margate
# Processing Record 11 of Set 5 | bairiki
# Processing Record 12 of Set 5 | la sarre
# Processing Record 13 of Set 5 | takoradi
# Processing Record 14 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 5 | maiduguri
# Processing Record 16 of Set 5 | yanchukan
# City not found. Skipping...
# Processing Record 17 of Set 5 | portland
# Processing Record 18 of Set 5 | litovko
# Processing Record 19 of Set 5 | yarmouth
# Processing Record 20 of Set 5 | chuy
# Processing Record 21 of Set 5 | guerrero negro
# Processing Record 22 of Set 5 | morris
# Processing Record 23 of Set 5 | vendome
# Processing Record 24 of Set 5 | upernavik
# Processing Record 25 of Set 5 | namatanai
# Processing Record 26 of Set 5 | hambantota
# Processing Record 27 of Set 5 | san policarpo
# Processing Record 28 of Set 5 | ilulissat
# Processing Record 29 of Set 5 | iqaluit
# Processing Record 30 of Set 5 | wakkanai
# Processing Record 31 of Set 5 | minot
# Processing Record 32 of Set 5 | rawson
# Processing Record 33 of Set 5 | muros
# Processing Record 34 of Set 5 | beihai
# Processing Record 35 of Set 5 | berlevag
# Processing Record 36 of Set 5 | maniitsoq
# Processing Record 37 of Set 5 | daxian
# City not found. Skipping...
# Processing Record 38 of Set 5 | dauphin
# Processing Record 39 of Set 5 | paredon
# Processing Record 40 of Set 5 | de-kastri
# Processing Record 41 of Set 5 | bollnas
# Processing Record 42 of Set 5 | melfi
# Processing Record 43 of Set 5 | boyuibe
# Processing Record 44 of Set 5 | truth or consequences
# Processing Record 45 of Set 5 | srednekolymsk
# Processing Record 46 of Set 5 | bac lieu
# Processing Record 47 of Set 5 | beisfjord
# Processing Record 48 of Set 5 | oyama
# Processing Record 49 of Set 5 | sumkino
# Processing Record 50 of Set 5 | elizabeth city
# Processing Record 1 of Set 6 | san vicente
# Processing Record 2 of Set 6 | kastamonu
# Processing Record 3 of Set 6 | saint-pierre
# Processing Record 4 of Set 6 | husavik
# Processing Record 5 of Set 6 | cabra
# Processing Record 6 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 6 | vardo
# Processing Record 8 of Set 6 | spokane
# Processing Record 9 of Set 6 | codrington
# Processing Record 10 of Set 6 | grindavik
# Processing Record 11 of Set 6 | jalu
# Processing Record 12 of Set 6 | kargasok
# Processing Record 13 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 14 of Set 6 | vaitape
# Processing Record 15 of Set 6 | borujan
# City not found. Skipping...
# Processing Record 16 of Set 6 | harper
# Processing Record 17 of Set 6 | puttur
# Processing Record 18 of Set 6 | nijar
# Processing Record 19 of Set 6 | diego de almagro
# Processing Record 20 of Set 6 | valparai
# Processing Record 21 of Set 6 | igrim
# Processing Record 22 of Set 6 | tuatapere
# Processing Record 23 of Set 6 | bambanglipuro
# Processing Record 24 of Set 6 | eureka
# Processing Record 25 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 6 | mar del plata
# Processing Record 27 of Set 6 | crowley
# Processing Record 28 of Set 6 | fortuna
# Processing Record 29 of Set 6 | plouzane
# Processing Record 30 of Set 6 | cam pha
# City not found. Skipping...
# Processing Record 31 of Set 6 | magadan
# Processing Record 32 of Set 6 | kysyl-syr
# Processing Record 33 of Set 6 | rocha
# Processing Record 34 of Set 6 | golfito
# Processing Record 35 of Set 6 | hami
# Processing Record 36 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 6 | westport
# Processing Record 38 of Set 6 | naco
# Processing Record 39 of Set 6 | port-gentil
# Processing Record 40 of Set 6 | lata
# Processing Record 41 of Set 6 | henties bay
# Processing Record 42 of Set 6 | vestmannaeyjar
# Processing Record 43 of Set 6 | gola gokarannath
# Processing Record 44 of Set 6 | cidreira
# Processing Record 45 of Set 6 | bethel
# Processing Record 46 of Set 6 | kavaratti
# Processing Record 47 of Set 6 | keffi
# Processing Record 48 of Set 6 | salalah
# Processing Record 49 of Set 6 | ocampo
# Processing Record 50 of Set 6 | morro bay
# Processing Record 1 of Set 7 | tautira
# Processing Record 2 of Set 7 | cherskiy
# Processing Record 3 of Set 7 | fayaoue
# Processing Record 4 of Set 7 | ribeira grande
# Processing Record 5 of Set 7 | severo-kurilsk
# Processing Record 6 of Set 7 | daugavpils
# Processing Record 7 of Set 7 | honiara
# Processing Record 8 of Set 7 | okhotsk
# Processing Record 9 of Set 7 | moose factory
# Processing Record 10 of Set 7 | barinas
# Processing Record 11 of Set 7 | sitka
# Processing Record 12 of Set 7 | saint george
# Processing Record 13 of Set 7 | thurso
# Processing Record 14 of Set 7 | kyshtovka
# Processing Record 15 of Set 7 | strohonivka
# Processing Record 16 of Set 7 | don sak
# Processing Record 17 of Set 7 | havre-saint-pierre
# Processing Record 18 of Set 7 | tucuman
# Processing Record 19 of Set 7 | narsaq
# Processing Record 20 of Set 7 | chicama
# Processing Record 21 of Set 7 | rzhev
# Processing Record 22 of Set 7 | noumea
# Processing Record 23 of Set 7 | kilindoni
# Processing Record 24 of Set 7 | praia
# Processing Record 25 of Set 7 | kapit
# Processing Record 26 of Set 7 | coahuayana
# Processing Record 27 of Set 7 | popondetta
# Processing Record 28 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 7 | wahpeton
# Processing Record 31 of Set 7 | sambava
# Processing Record 32 of Set 7 | santa rosa
# Processing Record 33 of Set 7 | banda aceh
# Processing Record 34 of Set 7 | reconquista
# Processing Record 35 of Set 7 | wangqing
# Processing Record 36 of Set 7 | troitskoye
# Processing Record 37 of Set 7 | ixtapa
# Processing Record 38 of Set 7 | parrita
# Processing Record 39 of Set 7 | lukh
# Processing Record 40 of Set 7 | gat
# Processing Record 41 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 42 of Set 7 | broken hill
# Processing Record 43 of Set 7 | vigrestad
# Processing Record 44 of Set 7 | bambous virieux
# Processing Record 45 of Set 7 | mandurah
# Processing Record 46 of Set 7 | paamiut
# Processing Record 47 of Set 7 | vangaindrano
# Processing Record 48 of Set 7 | hudiksvall
# Processing Record 49 of Set 7 | vila velha
# Processing Record 50 of Set 7 | lishan
# Processing Record 1 of Set 8 | ji-parana
# City not found. Skipping...
# Processing Record 2 of Set 8 | kampot
# Processing Record 3 of Set 8 | antalaha
# Processing Record 4 of Set 8 | cairns
# Processing Record 5 of Set 8 | naryan-mar
# Processing Record 6 of Set 8 | vanavara
# Processing Record 7 of Set 8 | clonakilty
# Processing Record 8 of Set 8 | escanaba
# Processing Record 9 of Set 8 | pisco
# Processing Record 10 of Set 8 | nalut
# Processing Record 11 of Set 8 | lethem
# Processing Record 12 of Set 8 | pangnirtung
# Processing Record 13 of Set 8 | da nang
# Processing Record 14 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 8 | bud
# Processing Record 16 of Set 8 | astana
# Processing Record 17 of Set 8 | murashi
# Processing Record 18 of Set 8 | omsukchan
# Processing Record 19 of Set 8 | filingue
# Processing Record 20 of Set 8 | mahebourg
# Processing Record 21 of Set 8 | sinjah
# City not found. Skipping...
# Processing Record 22 of Set 8 | stephenville
# Processing Record 23 of Set 8 | tayoltita
# Processing Record 24 of Set 8 | laguna
# Processing Record 25 of Set 8 | aklavik
# Processing Record 26 of Set 8 | druzhba
# Processing Record 27 of Set 8 | kumluca
# Processing Record 28 of Set 8 | nichinan
# Processing Record 29 of Set 8 | sisimiut
# Processing Record 30 of Set 8 | zhanakorgan
# Processing Record 31 of Set 8 | sola
# Processing Record 32 of Set 8 | helong
# Processing Record 33 of Set 8 | karratha
# Processing Record 34 of Set 8 | inirida
# Processing Record 35 of Set 8 | curaca
# Processing Record 36 of Set 8 | progreso
# Processing Record 37 of Set 8 | acapulco
# Processing Record 38 of Set 8 | ancud
# Processing Record 39 of Set 8 | lazaro cardenas
# Processing Record 40 of Set 8 | taltal
# Processing Record 41 of Set 8 | batemans bay
# Processing Record 42 of Set 8 | nouakchott
# Processing Record 43 of Set 8 | davila
# Processing Record 44 of Set 8 | athens
# Processing Record 45 of Set 8 | hamilton
# Processing Record 46 of Set 8 | araceli
# Processing Record 47 of Set 8 | grand gaube
# Processing Record 48 of Set 8 | hella
# Processing Record 49 of Set 8 | flinders
# Processing Record 50 of Set 8 | alofi
# Processing Record 1 of Set 9 | cansancao
# Processing Record 2 of Set 9 | emerald
# Processing Record 3 of Set 9 | anadyr
# Processing Record 4 of Set 9 | solton
# Processing Record 5 of Set 9 | boa viagem
# Processing Record 6 of Set 9 | brae
# Processing Record 7 of Set 9 | zaysan
# Processing Record 8 of Set 9 | dubbo
# Processing Record 9 of Set 9 | clyde river
# Processing Record 10 of Set 9 | visby
# Processing Record 11 of Set 9 | andenes
# Processing Record 12 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 13 of Set 9 | severnoye
# Processing Record 14 of Set 9 | belmonte
# Processing Record 15 of Set 9 | saint anthony
# Processing Record 16 of Set 9 | saldanha
# Processing Record 17 of Set 9 | komsomolskiy
# Processing Record 18 of Set 9 | mango
# Processing Record 19 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 9 | waihi beach
# Processing Record 21 of Set 9 | touros
# Processing Record 22 of Set 9 | champerico
# Processing Record 23 of Set 9 | karasjok
# Processing Record 24 of Set 9 | ayagoz
# Processing Record 25 of Set 9 | khormuj
# City not found. Skipping...
# Processing Record 26 of Set 9 | toora-khem
# Processing Record 27 of Set 9 | tessalit
# Processing Record 28 of Set 9 | gardez
# Processing Record 29 of Set 9 | pemangkat
# Processing Record 30 of Set 9 | nuuk
# Processing Record 31 of Set 9 | mikuni
# Processing Record 32 of Set 9 | half moon bay
# Processing Record 33 of Set 9 | sao felix do xingu
# Processing Record 34 of Set 9 | bizhbulyak
# Processing Record 35 of Set 9 | skaelskor
# Processing Record 36 of Set 9 | amapa
# Processing Record 37 of Set 9 | palmer
# Processing Record 38 of Set 9 | miura
# Processing Record 39 of Set 9 | yakeshi
# Processing Record 40 of Set 9 | serra talhada
# Processing Record 41 of Set 9 | westerland
# Processing Record 42 of Set 9 | bastrop
# Processing Record 43 of Set 9 | sao miguel do araguaia
# Processing Record 44 of Set 9 | chokurdakh
# Processing Record 45 of Set 9 | camocim
# Processing Record 46 of Set 9 | nome
# Processing Record 47 of Set 9 | nador
# Processing Record 48 of Set 9 | havelock
# Processing Record 49 of Set 9 | ridgecrest
# Processing Record 50 of Set 9 | hudson bay
# Processing Record 1 of Set 10 | lagoa
# Processing Record 2 of Set 10 | sinnamary
# Processing Record 3 of Set 10 | yamada
# Processing Record 4 of Set 10 | novyy urengoy
# Processing Record 5 of Set 10 | matamoros
# Processing Record 6 of Set 10 | siayan
# Processing Record 7 of Set 10 | barcelos
# Processing Record 8 of Set 10 | talas
# Processing Record 9 of Set 10 | victoria
# Processing Record 10 of Set 10 | rockport
# Processing Record 11 of Set 10 | bilma
# Processing Record 12 of Set 10 | bama
# Processing Record 13 of Set 10 | emiliano zapata
# Processing Record 14 of Set 10 | zhezkazgan
# Processing Record 15 of Set 10 | paralimni
# Processing Record 16 of Set 10 | dumas
# Processing Record 17 of Set 10 | asilah
# Processing Record 18 of Set 10 | la ronge
# Processing Record 19 of Set 10 | lichinga
# Processing Record 20 of Set 10 | kuching
# Processing Record 21 of Set 10 | opuwo
# Processing Record 22 of Set 10 | dembi dolo
# Processing Record 23 of Set 10 | canatlan
# Processing Record 24 of Set 10 | macusani
# Processing Record 25 of Set 10 | chateaubelair
# Processing Record 26 of Set 10 | saint-georges
# Processing Record 27 of Set 10 | mehamn
# Processing Record 28 of Set 10 | barra patuca
# Processing Record 29 of Set 10 | lajas
# Processing Record 30 of Set 10 | penzance
# Processing Record 31 of Set 10 | mariakani
# Processing Record 32 of Set 10 | talnakh
# Processing Record 33 of Set 10 | wanaka
# Processing Record 34 of Set 10 | nyurba
# Processing Record 35 of Set 10 | joao pinheiro
# Processing Record 36 of Set 10 | usinsk
# Processing Record 37 of Set 10 | otradnoye
# Processing Record 38 of Set 10 | verkhnyaya inta
# Processing Record 39 of Set 10 | qaqortoq
# Processing Record 40 of Set 10 | vanimo
# Processing Record 41 of Set 10 | sweetwater
# Processing Record 42 of Set 10 | kaili
# Processing Record 43 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 44 of Set 10 | honningsvag
# Processing Record 45 of Set 10 | banmo
# City not found. Skipping...
# Processing Record 46 of Set 10 | chapais
# Processing Record 47 of Set 10 | port augusta
# Processing Record 48 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 10 | warrnambool
# Processing Record 50 of Set 10 | ulu-telyak
# Processing Record 1 of Set 11 | naukot
# Processing Record 2 of Set 11 | san rafael
# Processing Record 3 of Set 11 | khuzhir
# Processing Record 4 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 11 | onega
# Processing Record 6 of Set 11 | khani
# Processing Record 7 of Set 11 | pozo colorado
# Processing Record 8 of Set 11 | alyangula
# Processing Record 9 of Set 11 | gweta
# Processing Record 10 of Set 11 | eskisehir
# Processing Record 11 of Set 11 | ferme-neuve
# Processing Record 12 of Set 11 | hibbing
# Processing Record 13 of Set 11 | evensk
# Processing Record 14 of Set 11 | pulaski
# Processing Record 15 of Set 11 | baranoa
# Processing Record 16 of Set 11 | conceicao do araguaia
# Processing Record 17 of Set 11 | pa daet
# Processing Record 18 of Set 11 | nushki
# Processing Record 19 of Set 11 | capoterra
# Processing Record 20 of Set 11 | nanzhang
# Processing Record 21 of Set 11 | kinna
# Processing Record 22 of Set 11 | clearwater
# Processing Record 23 of Set 11 | lorengau
# Processing Record 24 of Set 11 | zhigansk
# Processing Record 25 of Set 11 | reshetylivka
# Processing Record 26 of Set 11 | candelaria
# Processing Record 27 of Set 11 | bukachacha
# Processing Record 28 of Set 11 | careiro da varzea
# Processing Record 29 of Set 11 | tura
# Processing Record 30 of Set 11 | tungkang
# City not found. Skipping...
# Processing Record 31 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 32 of Set 11 | ilmajoki
# Processing Record 33 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 34 of Set 11 | beni
# Processing Record 35 of Set 11 | zhireken
# Processing Record 36 of Set 11 | mount gambier
# Processing Record 37 of Set 11 | tala
# Processing Record 38 of Set 11 | sur
# Processing Record 39 of Set 11 | ha giang
# Processing Record 40 of Set 11 | awjilah
# Processing Record 41 of Set 11 | agadez
# Processing Record 42 of Set 11 | hun
# Processing Record 43 of Set 11 | lyngdal
# Processing Record 44 of Set 11 | mansa
# Processing Record 45 of Set 11 | kismayo
# Processing Record 46 of Set 11 | rio muerto
# Processing Record 47 of Set 11 | banda
# Processing Record 48 of Set 11 | livingstone
# Processing Record 49 of Set 11 | pakwach
# City not found. Skipping...
# Processing Record 50 of Set 11 | kerrobert
# Processing Record 1 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 2 of Set 12 | tual
# Processing Record 3 of Set 12 | marawi
# Processing Record 4 of Set 12 | atar
# Processing Record 5 of Set 12 | belyy yar
# Processing Record 6 of Set 12 | pindiga
# Processing Record 7 of Set 12 | morondava
# Processing Record 8 of Set 12 | garden city
# Processing Record 9 of Set 12 | warwick
# Processing Record 10 of Set 12 | cabedelo
# Processing Record 11 of Set 12 | bandarbeyla
# Processing Record 12 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 12 | tiarei
# Processing Record 15 of Set 12 | mayo
# Processing Record 16 of Set 12 | buluang
# Processing Record 17 of Set 12 | mwandiga
# Processing Record 18 of Set 12 | krasnaya gora
# Processing Record 19 of Set 12 | wasilla
# Processing Record 20 of Set 12 | wuwei
# Processing Record 21 of Set 12 | olafsvik
# Processing Record 22 of Set 12 | we
# City not found. Skipping...
# Processing Record 23 of Set 12 | lapua
# Processing Record 24 of Set 12 | suntar
# Processing Record 25 of Set 12 | port blair
# Processing Record 26 of Set 12 | minusinsk
# Processing Record 27 of Set 12 | turayf
# Processing Record 28 of Set 12 | baringo
# Processing Record 29 of Set 12 | shcholkine
# City not found. Skipping...
# Processing Record 30 of Set 12 | fengrun
# Processing Record 31 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 32 of Set 12 | ucluelet
# Processing Record 33 of Set 12 | usta muhammad
# Processing Record 34 of Set 12 | proteccion
# Processing Record 35 of Set 12 | mitsamiouli
# Processing Record 36 of Set 12 | ahipara
# Processing Record 37 of Set 12 | khromtau
# Processing Record 38 of Set 12 | buchanan
# Processing Record 39 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 12 | paravola
# Processing Record 41 of Set 12 | huarmey
# Processing Record 42 of Set 12 | rosarito
# Processing Record 43 of Set 12 | megion
# Processing Record 44 of Set 12 | shache
# Processing Record 45 of Set 12 | quetzaltenango
# Processing Record 46 of Set 12 | adrar
# Processing Record 47 of Set 12 | san antonio
# Processing Record 48 of Set 12 | praia da vitoria
# Processing Record 49 of Set 12 | suao
# City not found. Skipping...
# Processing Record 50 of Set 12 | kalmunai
# Processing Record 1 of Set 13 | auki
# Processing Record 2 of Set 13 | borborema
# Processing Record 3 of Set 13 | olinda
# Processing Record 4 of Set 13 | santa fe
# Processing Record 5 of Set 13 | verdun
# Processing Record 6 of Set 13 | fare
# Processing Record 7 of Set 13 | saquena
# Processing Record 8 of Set 13 | port hardy
# Processing Record 9 of Set 13 | moulins
# Processing Record 10 of Set 13 | kattivakkam
# Processing Record 11 of Set 13 | izumo
# Processing Record 12 of Set 13 | ekhabi
# Processing Record 13 of Set 13 | konevo
# Processing Record 14 of Set 13 | luba
# Processing Record 15 of Set 13 | northport
# Processing Record 16 of Set 13 | ust-nera
# Processing Record 17 of Set 13 | serenje
# Processing Record 18 of Set 13 | juneau
# Processing Record 19 of Set 13 | jiwani
# Processing Record 20 of Set 13 | tshikapa
# Processing Record 21 of Set 13 | ambovombe
# Processing Record 22 of Set 13 | muzquiz
# City not found. Skipping...
# Processing Record 23 of Set 13 | kangaatsiaq
# Processing Record 24 of Set 13 | tunxi
# City not found. Skipping...
# Processing Record 25 of Set 13 | pontal do parana
# Processing Record 26 of Set 13 | belaya gora
# Processing Record 27 of Set 13 | hirara
# Processing Record 28 of Set 13 | ojinaga
# Processing Record 29 of Set 13 | leh
# Processing Record 30 of Set 13 | ternate
# Processing Record 31 of Set 13 | faya
# Processing Record 32 of Set 13 | sapa
# Processing Record 33 of Set 13 | korla
# Processing Record 34 of Set 13 | vao
# Processing Record 35 of Set 13 | san carlos de bariloche
# Processing Record 36 of Set 13 | orlik
# Processing Record 37 of Set 13 | paraiso
# Processing Record 38 of Set 13 | zyryanka
# Processing Record 39 of Set 13 | agueda
# Processing Record 40 of Set 13 | sciacca
# Processing Record 41 of Set 13 | burica
# City not found. Skipping...
# Processing Record 42 of Set 13 | vyyezdnoye
# Processing Record 43 of Set 13 | thinadhoo
# Processing Record 44 of Set 13 | saskatoon
# Processing Record 45 of Set 13 | san luis
# Processing Record 46 of Set 13 | shimoda
# Processing Record 47 of Set 13 | cacapava do sul
# Processing Record 48 of Set 13 | san quintin
# Processing Record 49 of Set 13 | mildura
# Processing Record 50 of Set 13 | fatezh
# Processing Record 1 of Set 14 | kyra
# Processing Record 2 of Set 14 | williams lake
# Processing Record 3 of Set 14 | ravar
# Processing Record 4 of Set 14 | carlsbad
# Processing Record 5 of Set 14 | yerofey pavlovich
# Processing Record 6 of Set 14 | lewistown
# Processing Record 7 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 14 | helena
# Processing Record 9 of Set 14 | pacific grove
# Processing Record 10 of Set 14 | dumai
# Processing Record 11 of Set 14 | gravdal
# Processing Record 12 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 13 of Set 14 | lodja
# Processing Record 14 of Set 14 | pokhara
# Processing Record 15 of Set 14 | aginskoye
# Processing Record 16 of Set 14 | cedar city
# Processing Record 17 of Set 14 | saint-augustin
# Processing Record 18 of Set 14 | grahamstown
# Processing Record 19 of Set 14 | kathmandu
# Processing Record 20 of Set 14 | odweyne
# Processing Record 21 of Set 14 | caravelas
# Processing Record 22 of Set 14 | pontian kecil
# Processing Record 23 of Set 14 | gaoua
# Processing Record 24 of Set 14 | rawlins
# Processing Record 25 of Set 14 | tonj
# Processing Record 26 of Set 14 | coos bay
# Processing Record 27 of Set 14 | novospasskoye
# Processing Record 28 of Set 14 | kozachi laheri
# Processing Record 29 of Set 14 | coxim
# Processing Record 30 of Set 14 | bar harbor
# Processing Record 31 of Set 14 | pangkalanbuun
# Processing Record 32 of Set 14 | ostersund
# Processing Record 33 of Set 14 | ritchie
# Processing Record 34 of Set 14 | krasnopillya
# Processing Record 35 of Set 14 | spring hill
# Processing Record 36 of Set 14 | taitung
# Processing Record 37 of Set 14 | mandan
# Processing Record 38 of Set 14 | ratnagiri
# Processing Record 39 of Set 14 | savinka
# Processing Record 40 of Set 14 | beloha
# Processing Record 41 of Set 14 | aksu
# Processing Record 42 of Set 14 | pangai
# Processing Record 43 of Set 14 | yangmei
# Processing Record 44 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 46 of Set 14 | kralendijk
# Processing Record 47 of Set 14 | college
# Processing Record 48 of Set 14 | severnyy
# Processing Record 49 of Set 14 | tommot
# Processing Record 50 of Set 14 | baruun-urt
# Processing Record 1 of Set 15 | ribas do rio pardo
# Processing Record 2 of Set 15 | kulhudhuffushi
# Processing Record 3 of Set 15 | fort nelson
# Processing Record 4 of Set 15 | plastun
# Processing Record 5 of Set 15 | bazarnyye mataki
# Processing Record 6 of Set 15 | hofn
# Processing Record 7 of Set 15 | luganville
# Processing Record 8 of Set 15 | iwanai
# Processing Record 9 of Set 15 | ust-kuyga
# Processing Record 10 of Set 15 | boyolangu
# Processing Record 11 of Set 15 | jenjarom
# Processing Record 12 of Set 15 | fairbanks
# Processing Record 13 of Set 15 | yeppoon
# Processing Record 14 of Set 15 | pochutla
# Processing Record 15 of Set 15 | mogochin
# City not found. Skipping...
# Processing Record 16 of Set 15 | kozhva
# Processing Record 17 of Set 15 | zaozerne
# Processing Record 18 of Set 15 | beringovskiy
# Processing Record 19 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 20 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 15 | sokoni
# Processing Record 22 of Set 15 | presidente dutra
# Processing Record 23 of Set 15 | karpathos
# Processing Record 24 of Set 15 | promyshlennyy
# Processing Record 25 of Set 15 | benguela
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Mwinilunga -11.7358   24.4293     60.67        96          83        1.01
# 1    Jamestown  42.0970  -79.2353     55.04        48           0        6.91
# 2       Sangar  63.9242  127.4739      1.65        93         100        4.92
# 3   Kaitangata -46.2817  169.8464     54.19        64          60       20.18
# 4        Tiksi  71.6872  128.8694    -10.43       100         100        3.40
# 5     Coquimbo -29.9533  -71.3436     61.72        77           6        2.42
# 6     La Palma  33.8464 -118.0467     86.67        65           0       10.36
# 7    Saskylakh  71.9167  114.0833    -13.00        97          62        4.38
# 8  Sakaiminato  35.5500  133.2333     60.78        59          20       14.97
# 9  Tuktoyaktuk  69.4541 -133.0374     -5.80        71          20        9.22
#
#   Country                 Date Current Description
# 0      ZM  2022-04-06 00:40:27       broken clouds
# 1      US  2022-04-06 00:36:01           clear sky
# 2      RU  2022-04-06 00:40:28     overcast clouds
# 3      NZ  2022-04-06 00:40:28       broken clouds
# 4      RU  2022-04-06 00:40:28     overcast clouds
# 5      CL  2022-04-06 00:37:15           clear sky
# 6      US  2022-04-06 00:40:29           clear sky
# 7      RU  2022-04-06 00:40:29       broken clouds
# 8      JP  2022-04-06 00:40:29          few clouds
# 9      CA  2022-04-06 00:40:30          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
